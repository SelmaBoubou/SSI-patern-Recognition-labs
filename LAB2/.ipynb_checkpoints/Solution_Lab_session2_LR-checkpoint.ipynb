# %% [markdown]
# # Lab session 2 ---- Logistic Regression

# %% [markdown]
# Student: Boudissa Selma
# Date:21/03/18

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## I. Introduction
# In this exercise, we will implement logistic regression.
# Note that you should have completed Lab1, and, in particular, understand the gradient descent algorithm.

# %% [markdown]
# ## II. Logistic regression
# Suppose that you are the administrator of a university department and you want to determine each applicant’s chance of admission based on their results on two exams.
# The file lab2data1.txt contains historical data from previous applicants. The first two columns correspond to the applicant’s scores on the two exams and the last column is the admission decision; a value equals to 0 means the applicant was not selected, while a value equals to 1 means that he/she was accepted.
# Your task is to build a classifier that will estimate an applicant’s probability of admission based on his scores in the two exams.

# %% [markdown]
# ### Solution Question 1

# %%
def plotData(X,y):
    idx = np.arange(0, X.shape[0])
    pos = idx [y == 1]
    neg = idx [y == 0]
    # plotting     
    plt.figure()
    plt.scatter(X[pos, 0], X[pos, 1], c='r', label='Not admitted')
    plt.scatter(X[neg, 0], X[neg, 1], c='k', label='admitted')
    plt.xlabel('Exam score 1')
    plt.xlabel('Exam score 2')
    plt.legend()
    plt.show()
    
# load the data
data = np.loadtxt("lab2data1.txt", delimiter=',')
#inpack the data
X = np.atleast_2d(data[:,:-1])
# target 
y = data[:,-1]
# print
print('There is {} samples and {} features'.format(X.shape[0],X.shape[1]))
plotData(X, y)
# Out:
# There is 100 samples and 2 features

# %%
# other solution

# load the data
data = np.loadtxt("lab2data1.txt", delimiter=',')
X = np.atleast_2d(data[:, :-1])
y = data[:, -1]

X1 = data[:, 0]
X2 = data[:, 1]

#print the data
plt.scatter(X1,X2 , c=y , )
plt.xlabel('Exam 1 score')
plt.ylabel('Exam 2 score')
plt.legend()
plt.show()
# Out:
# C:\Users\Selma\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:531: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %% [markdown]
# ### Solution Question 2

# %%
# Sigmoid function
def sigmoid(x):
    x =np.array(x).flatten()
    return (1/(1+np.exp(-x)))

x_tmp = np.linspace(-10,10,100)
y_tmp = sigmoid(x_tmp)

#plt.figure()
plt.plot(x_tmp, y_tmp,'r')
plt.title('Sigmoid function')
plt.show()

# %% [markdown]
# ### Solution Question 3

# %%
def costfunction(theta, X, y, intercept=False):
    if intercept:
        X_ = np.asmatrix(X)
    else:
        intercept_array = np.ones((X.shape[0], 1))
        X_= (np.asmatrix(np.hstack((intercept_array, X))))
        n_samples = X_.shape[0]
        n_feature = X_.shape[1]
        hypothesis = sigmoid(X_.dot(theta).T)
    #print(n_samples)
        J = (1.0/n_samples) * np.sum(-y * np.log(hypothesis) - (1- y) * np.log(1- hypothesis))
    #print(hypothesis)
        return J 
     
        
        
def costFunction_der(theta, X, y, intercept=False):
    if intercept:
        X_ = np.asmatrix(X)
    else:
            intercept_array = np.ones((X.shape[0], 1))
            # add intercept
            X_ = np.asmatrix(np.hstack([intercept_array, X]))
          
            n_samples = X_.shape[0]
            n_feature = X_.shape[1]
            hypothesis = sigmoid(X_.dot(theta).T)
            error = hypothesis - y
          
            grad = []
          
            for i in range(0, theta.shape[0]):
                grad.append(1./n_samples * np.sum(error * (X_[:,i])))
    return grad

# %%
[n_samples, n_features] = X.shape

initial_theta = np.zeros((n_features+1, 1))

cost = costfunction(initial_theta, X, y)
grad = costFunction_der(initial_theta, X, y)


print(cost)
print(grad)
# Out:
# 0.69314718056
# [-0.10000000000000001, -12.009216589291153, -11.262842205513593]

# %% [markdown]
# ### Solution Question 4

# %%
#import scipy.optimize as opt
#Result = opt.minimize(fun = costfunction, x0 = initial_theta, args = (X,y), 
 #                             method = 'TNC', jac=costFunction_der)

#theta = Result.x

#print('The results from the optimization w ={}'.format(theta))


import scipy.optimize as opt
ncols = np.size(X, 1)
w_init = np.zeros((ncols + 1, 1))

Results = opt.minimize(costfunction, w_init, args=(X, y), method='TNC', jac = costFunction_der)

theta = Results.x

print('The results from the optimization w ={}'.format(theta))
# Out:
# The results from the optimization w =[-25.16131859   0.20623159   0.20147149]

# %% [markdown]
# ### Solution Question 5

# %%
# Teacher's code
#def plotDecisionBoundary(theta, X, y, option):
 #   idx = np.arrange(0, X.shape[0])
#  pos = idx [y == 1]
#    neg = idx [y == 0]
#    #plot the figure
#    plt.scatter(X[pos, 0], X[pos, 1], c='r')
#    plt.scatter(X[neg, 0], X[neg, 1], c='k')
    #
#    plt.xlabel('Exam score 1')
#    plt.ylabel('Exam score 2')
    
#    if option =='line':
        
#        plot_x = np.array([min(X[:,1])-2, max(x[:,1])+2])
#        plot_y = (-1/theta[2])*(theta[1]*plot_x + theta[0])
#        print(plot_x)
#        print(plot_y)
#        plt.plot(plot_x, plot_y)
       
#        plot.show()
        
# Other way to answer the question 

#Data with positive labels (label = 1)
idx = (y == 1)
Xpos = X[idx,:]
p1 = plt.scatter(Xpos[:,0], Xpos[:,1], marker = '+', color = 'k')

#Data with negative labels (label = 0)
idx = (y == 0)
Xneg = X[idx,:]
p2 = plt.scatter(Xneg[:,0], Xneg[:,1], marker = 'o', color = 'y')

# Create scatter plot of the labelled datapoints
plt.xlabel('Exam 1 score')
plt.ylabel('Exam 2 score')
plt.legend([p1, p2], ["Admitted", "Not Admitted"])

# plot the decision boundary
x_w = np.linspace(35.0, 100.0, num = 1000)
y_w = -(theta[0] + theta[1]*x_w)/theta[2] 

plt.plot(x_w, y_w)

plt.show()

# %% [markdown]
# ### Solution Question 6

# %%
# This code will provide the training accuracy of the 
# model which should be around 89 %


def predict(theta, X):
    '''Predict whether the label
    is 0 or 1 using learned logistic
    regression parameters '''
    m, n = X.shape
    p = zeros(shape=(m, 1))

    h = sigmoid(X.dot(theta.T))

    for it in range(0, h.shape[0]):
        if h[it] > 0.5:
            p[it, 0] = 1
        else:
            p[it, 0] = 0

    return p

#Compute accuracy on our training set
p = predict(np.array(theta), it)
print ('Train Accuracy: %f' % ((y[where(p == y)].size / float(y.size)) * 100.0))
#print('The results from the optimization w ={}'.format(theta))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-167-03733420f245> in <module>()
#      21
#      22 #Compute accuracy on our training set
# ---> 23 p = predict(np.array(theta), it)
#      24 print ('Train Accuracy: %f' % ((y[where(p == y)].size / float(y.size)) * 100.0))
#      25 #print('The results from the optimization w ={}'.format(theta))
#
# NameError: name 'it' is not defined

# %% [markdown]
# ### III. Logistic regression with regularization
# In this part, we will see the full power of logistic regression. Suppose that you are the production manager of a factory that produces microchips. After production, each microchip goes through various tests to ensure it functions correctly.
# The file lab2data2.txt contains test results for some microchips on two tests. The first two columns correspond to the tests results, and the last column indicates whether the microchip should be accepted or not; 0 means rejected while 1 means accepted.
# Using your function plotData(X,y), you can visualize the training data. As can be seen in Figure 3, this data is clearly not linearly separable, so a straight-forward application of logistic regression will not find a good decision boundary.

# %% [markdown]
# ### Solution Question 1

# %%
# First step load the data2
# load the data
data = np.loadtxt("lab2data2.txt", delimiter=',')

# %%
def map_feature(x1, x2):
    '''
    Maps the two input features to quadratic features.
    Returns a new feature array with more features, comprising of
    X1, X2, X1 ** 2, X2 ** 2, X1*X2, X1*X2 ** 2, etc...
    Inputs X1, X2 must be the same size
    '''
    x1.shape = (x1.size, 1)
    x2.shape = (x2.size, 1)
    degree = 6
    out = ones(shape=(x1[:, 0].size, 1))

    m, n = np.shape

    for i in range(1, degree + 1):
        for j in range(i + 1):
            r = (x1 ** (i - j)) * (x2 ** j)
            out = append(out, r, axis=1)

    return out

# %%
def plotData(X,y):
    idx = np.arange(0,X.shape[0])
    pos = idx[y == 1]
    neg = idx[y == 0]
    plt.figure()
    plt.scatter(X[pos,0], X[pos, 1], marker='+', c='r')
    plt.scatter(X[neg,0], X[neg, 1], marker='o', c='b')
    plt.title('Matplot scatter plot')
    plt.xlabel('Microchip Test 1')
    plt.ylabel('Microchip Test 2')
    plt.legend(['y = 1', 'y = 0'])
    plt.show()


# read the data from the txt file
data = np.loadtxt('lab2data2.txt', delimiter=',')
# unpack the data
# data
X = data[:, 0:2]
# target
y = data[:, 2]
print('There is {} samples and {} features'.format(X.shape[0], X.shape[1]))
plotData(X, y)
# Out:
# There is 118 samples and 2 features

# %% [markdown]
# ### Solution Question 2

# %%
def costfunction(theta, X, y, intercept=False):
    if intercept:
        X_ = np.asmatrix(X)
    else: 
        intercept_array = np.ones((X.shape[0], 1))
        X_= (np.asmatrix(np.hstack((intercept_array, X))))
    n_samples = X_.shape[0]
    n_feature = X_.shape[1] 
    hypothesis = sigmoid(X_.dot(theta).T)
    J = (1./n_samples) * np.sum(-y * np.log(hypothesis) - (1- y) * np.log(1- hypothesis))
    #print(hypothesis)
    return J  

def costFunction_der(theta, X, y, intercept=False):
    if intercept:
        X_ = np.asmatrix(X)
    else:
            intercept_array = np.ones((X.shape[0], 1))
            # add intercept
            X_ = np.asmatrix(np.hstack([intercept_array, X]))
           
            n_samples = X_.shape[0]
            n_feature = X_.shape[1]
            hypothesis = sigmoid(X_.dot(theta).T)
            error = hypothesis - y
           
            grad = []
           
            for i in range(0, theta.shape[0]):
                grad.append(1./n_samples * np.sum(error * (X_[:,i])))
    return grad

# %%
[n_samples, n_features] = X.shape

initial_theta = np.zeros((n_features+1, 1))

cost = costfunction(initial_theta, X, y)
grad = costFunction_der(initial_theta, X, y)


print(cost)
print(grad)
# Out:
# 0.69314718056
# [0.0084745762711864406, 0.018788093220338985, 7.7771186440672591e-05]

# %% [markdown]
# ### Solution Question 3

# %%
from numpy import loadtxt, where, zeros, e, array, log, ones, append, linspace
from pylab import scatter, show, legend, xlabel, ylabel, contour, title
from scipy.optimize import fmin_bfgs

# %%
#Plot Decision Boundary on training data
def decisionBoundary(theta, X, y):
    
    #plot data 
    plotData(X[:,2:3],y)
    
    
    if np.size([X,1])<= 3:
        x_p = (min[X[:,2]-2], max[X[:,2]]+2)
        y_p = (-1/theta[2])*(theta[1]*x_p +theta[0])
        p = plt.plot(x_p,y_p)
        plt.legend('Admitted', 'Not admitted', 'Decision boundary')
        plt.axis([30, 100, 30, 100])
        
        
             
    else:
        u = np.linspace(-1, 1.5, 50)
        v = np.linspace(-1, 1.5, 50)
        z = np.zeros((len(u), len(v)))
        for i in range(len(u)):
            for j in range(len(v)):
                z[i, j] = (map_feature(np.array(u[i]), np.array(v[j])),theta)
                
            return
        return
    z = np.transpose(z) # Z transpose
    contour(u,v,z, levels=[0], linewidth=2)
    
        
plt.show(decisionBoundary(theta,X,y))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-144-8dd4c74d63fb> in <module>()
#      29
#      30
# ---> 31 plt.show(decisionBoundary(theta,X,y))
#      32
#      33
#
# <ipython-input-144-8dd4c74d63fb> in decisionBoundary(theta, X, y)
#       3
#       4     #plot data
# ----> 5     plotData(X[:,2:3],y)
#       6
#       7
#
# <ipython-input-140-30268077a592> in plotData(X, y)
#       4     neg = idx[y == 0]
#       5     plt.figure()
# ----> 6     plt.scatter(X[pos,0], X[pos, 1], marker='+', c='r')
#       7     plt.scatter(X[neg,0], X[neg, 1], marker='o', c='b')
#       8     plt.title('Matplot scatter plot')
#
# IndexError: index 0 is out of bounds for axis 1 with size 0

# %% [markdown]
# ### Solution Question 4
